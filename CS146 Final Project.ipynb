# %% [markdown]
# # CS146 Final Project
#
# ## Modeling and forecasting atmospheric CO₂ from 1958 into the future
#
# -------

# %% [markdown]
# ### Data reshaping

# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
#Import original data file
imported_data = pd.read_csv('weekly_in_situ_co2_mlo.csv',names=['Date','CO2 ppm'])

# %%
#Take a look
imported_data.head()
# Out:
#          Date  CO2 ppm
# 0  1958-03-29   316.19
# 1  1958-04-05   317.31
# 2  1958-04-12   317.69
# 3  1958-04-19   317.58
# 4  1958-04-26   316.48

# %%
dates = imported_data['Date']
co2_levels = imported_data['CO2 ppm']

# %%
#function to calculate difference in days between two dates
def days_between(d1, d2):
    d1 = datetime.strptime(d1, "%Y-%m-%d")
    d2 = datetime.strptime(d2, "%Y-%m-%d")
    return abs((d2 - d1).days)


days = [0]
for i in range(0, len(dates)-1):
      days.append(dates[-1]+days_between(data.iloc[i,0], data.iloc[i+1,0]))

# %%
dates
# Out:
# 0       1958-03-29
# 1       1958-04-05
# 2       1958-04-12
# 3       1958-04-19
# 4       1958-04-26
# 5       1958-05-03
# 6       1958-05-17
# 7       1958-05-24
# 8       1958-07-05
# 9       1958-07-12
# 10      1958-07-19
# 11      1958-07-26
# 12      1958-08-02
# 13      1958-08-09
# 14      1958-08-16
# 15      1958-08-30
# 16      1958-09-06
# 17      1958-11-08
# 18      1958-11-15
# 19      1958-11-22
# 20      1958-11-29
# 21      1958-12-06
# 22      1958-12-13
# 23      1958-12-20
# 24      1958-12-27
# 25      1959-01-03
# 26      1959-01-10
# 27      1959-01-17
# 28      1959-01-24
# 29      1959-01-31
#            ...
# 3180    2020-07-25
# 3181    2020-08-01
# 3182    2020-08-08
# 3183    2020-08-15
# 3184    2020-08-22
# 3185    2020-08-29
# 3186    2020-09-05
# 3187    2020-09-12
# 3188    2020-09-19
# 3189    2020-09-26
# 3190    2020-10-03
# 3191    2020-10-10
# 3192    2020-10-17
# 3193    2020-10-24
# 3194    2020-10-31
# 3195    2020-11-07
# ...

# %%
plt.figure(figsize=(10,8))
plt.plot(imported_data['Date'],imported_data['CO2 ppm'])
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.xticks(np.arange(min(days), max(days), 1000),rotation=90)
plt.plot(dates,co2_levels)
plt.show()

# %%
2+3
# Out:
# 5
